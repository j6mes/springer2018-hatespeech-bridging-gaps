# %%
import tensorflow as tf

# %%
import random
import numpy as np

from tqdm import tqdm

from dataset_reader import DataSet
from features import features
from preprocessing import preprocess
from vocab import Vocab
from composite_dataset import CompositeDataset

# %%
racism = DataSet("racism_overlapfree")
sexism = DataSet("sexism_overlapfree")
neither = DataSet("neither_overlapfree")

# %%
data = CompositeDataset()
data.add_data('racism',racism)
data.add_data('sexism',sexism)
data.add_data('neither',neither)

train,dev,test,vocab = data.get_as_labelled()
# Out:
# 100%|██████████| 1579/1579 [00:01<00:00, 927.47it/s]
# 100%|██████████| 197/197 [00:00<00:00, 843.29it/s]
# 100%|██████████| 198/198 [00:00<00:00, 1033.49it/s]
# 100%|██████████| 2637/2637 [00:02<00:00, 1098.90it/s]
# 100%|██████████| 330/330 [00:00<00:00, 1102.77it/s]
# 100%|██████████| 330/330 [00:00<00:00, 1172.22it/s]
# 100%|██████████| 7008/7008 [00:05<00:00, 1399.76it/s]
# 100%|██████████| 876/876 [00:00<00:00, 1333.27it/s]
# 100%|██████████| 876/876 [00:00<00:00, 1268.92it/s]
# 100%|██████████| 1579/1579 [00:00<00:00, 7276.07it/s]
# 100%|██████████| 7008/7008 [00:00<00:00, 8607.73it/s]
# 100%|██████████| 2637/2637 [00:00<00:00, 6670.38it/s]

# %%
def onehot(vals):
    return (np.arange(num_classes)[:]==np.array(vals)[:,None]).astype(np.float32)

def bow(vals,vocab):
    vals = list(vals)
    arr = np.zeros((len(vals),num_feats))
    
    for idx,val in enumerate(vals):
        for key in val.keys():
            arr[idx,key] = val[key]
    
    return arr

# %%
num_classes = len(data.labels)
num_feats = len(vocab.vocab)

X_train,y_train = map(list,zip(*train))
X_dev,y_dev = map(list,zip(*dev))
X_test,y_test = map(list,zip(*test))

y_train = onehot(y_train) 
y_dev = onehot(y_dev)
y_test = onehot(y_test)

X_train = bow(map(vocab.lookup,X_train),vocab)
X_dev = bow(map(vocab.lookup,X_dev),vocab)
X_test = bow(map(vocab.lookup,X_test),vocab)

# %%
batch_size = 50
l2_lambda = 1e-3

graph = tf.Graph()

with graph.as_default():
    global_step = tf.Variable(0)
    learning_rate = tf.train.exponential_decay(0.5, global_step, 1000,0.8)

    train_data = tf.placeholder(tf.float32, [batch_size,num_feats])
    train_labels = tf.placeholder(tf.float32, [batch_size, num_classes])
    
    dev_data = tf.constant(X_dev.astype(np.float32))
    test_data = tf.constant(X_test.astype(np.float32))
    
    weights1 = tf.Variable(tf.truncated_normal([num_feats, num_classes]))
    biases1 = tf.Variable(tf.zeros([num_classes]))
    
    logits = tf.add(tf.matmul(train_data,weights1),biases1)
    
    loss = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(labels=train_labels, logits=logits)) + l2_lambda * (tf.nn.l2_loss(weights1) + tf.nn.l2_loss(biases1))
        
    optimizer = tf.train.GradientDescentOptimizer(learning_rate).minimize(loss,global_step=global_step)
    train_prediction = tf.nn.softmax(logits)
    dev_prediction = tf.nn.softmax(tf.matmul(dev_data, weights1) + biases1)
    test_prediction = tf.nn.softmax(tf.matmul(test_data, weights1) + biases1)

# %%
batch_size = 5
l2_lambda = 1e-3

hidden_size = 20

graph = tf.Graph()

with graph.as_default():
    global_step = tf.Variable(0)
    learning_rate = tf.train.exponential_decay(0.5, global_step, 1000,0.8)

    train_data = tf.placeholder(tf.float32, [batch_size,num_feats])
    train_labels = tf.placeholder(tf.float32, [batch_size, num_classes])
    
    dev_data = tf.constant(X_dev.astype(np.float32))
    test_data = tf.constant(X_test.astype(np.float32))
    
    weights1 = tf.Variable(tf.truncated_normal([num_feats, hidden_size]))
    biases1 = tf.Variable(tf.zeros([hidden_size]))
    
    weights2 = tf.Variable(tf.truncated_normal([hidden_size, num_classes]))
    biases2 = tf.Variable(tf.zeros([num_classes]))
    
    layer1 = tf.nn.relu(tf.add(tf.matmul(train_data,weights1),biases1))
    
    logits = tf.add(tf.matmul(layer1,weights2),biases2)
    
    loss = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(labels=train_labels, logits=logits)) + l2_lambda * (tf.nn.l2_loss(weights1) + tf.nn.l2_loss(biases1) + tf.nn.l2_loss(weights2) + tf.nn.l2_loss(biases2))
        
    optimizer = tf.train.GradientDescentOptimizer(learning_rate).minimize(loss,global_step=global_step)
    train_prediction = tf.nn.softmax(logits)
    dev_prediction = tf.nn.softmax(tf.add(tf.matmul(tf.nn.relu(tf.add(tf.matmul(dev_data,weights1),biases1)),weights2),biases2))
    test_prediction = tf.nn.softmax(tf.add(tf.matmul(tf.nn.relu(tf.add(tf.matmul(test_data,weights1),biases1)),weights2),biases2))

# %%
num_epochs = 30
num_steps = y_train.shape[0]*num_epochs//batch_size
print(num_steps)

def accuracy(predictions, labels):
    return (100.0 * np.sum(np.argmax(predictions, 1) == np.argmax(labels, 1)) / predictions.shape[0])

with tf.Session(graph=graph) as session:
    tf.global_variables_initializer().run()
    for step in range(num_steps):
        offset = (step * batch_size) % (y_train.shape[0] - batch_size)
        
        batch_data = X_train[offset:(offset + batch_size)]
        batch_labels = y_train[offset:(offset + batch_size), :]
        
        feed_dict = {train_data : batch_data, train_labels : batch_labels}
        _, l, predictions = session.run([optimizer, loss, train_prediction], feed_dict=feed_dict)
        
        if step % 100 == 0:
            print("Minibatch loss at step %d: %f" % (step, l))
            print("Minibatch accuracy: %.1f%%" % accuracy(predictions, batch_labels))
            
            print("VALIDATION accuracy: %.1f%%" % accuracy(dev_prediction.eval(), y_dev))
    print("FINAL TEST accuracy: %.1f%%" % accuracy(test_prediction.eval(), y_test))
# Out:
# 67344
# Minibatch loss at step 0: 175.996414
# Minibatch accuracy: 60.0%
# VALIDATION accuracy: 62.4%
# Minibatch loss at step 100: 157.179459
# Minibatch accuracy: 40.0%
# VALIDATION accuracy: 62.4%
# Minibatch loss at step 200: 142.139786
# Minibatch accuracy: 80.0%
# VALIDATION accuracy: 62.4%
# Minibatch loss at step 300: 129.878143
# Minibatch accuracy: 40.0%
# VALIDATION accuracy: 62.4%
# Minibatch loss at step 400: 118.504578
# Minibatch accuracy: 40.0%
# VALIDATION accuracy: 62.4%
# Minibatch loss at step 500: 108.154602
# Minibatch accuracy: 60.0%
# VALIDATION accuracy: 62.4%
# Minibatch loss at step 600: 99.725594
# Minibatch accuracy: 20.0%
# VALIDATION accuracy: 62.4%
# Minibatch loss at step 700: 90.952110
# Minibatch accuracy: 60.0%
# VALIDATION accuracy: 62.4%
# Minibatch loss at step 800: 83.555519
# Minibatch accuracy: 60.0%
# VALIDATION accuracy: 62.4%
# Minibatch loss at step 900: 77.139366
# Minibatch accuracy: 60.0%
# VALIDATION accuracy: 62.4%
# Minibatch loss at step 1000: 70.892387
# Minibatch accuracy: 80.0%
# VALIDATION accuracy: 62.4%
# Minibatch loss at step 1100: 65.398468
# Minibatch accuracy: 100.0%
# VALIDATION accuracy: 62.4%
# Minibatch loss at step 1200: 61.438370
# Minibatch accuracy: 20.0%
# VALIDATION accuracy: 62.4%
# Minibatch loss at step 1300: 56.898956
# Minibatch accuracy: 40.0%
# VALIDATION accuracy: 62.4%
# Minibatch loss at step 1400: 52.544830
# Minibatch accuracy: 60.0%
# VALIDATION accuracy: 62.4%
# Minibatch loss at step 1500: 49.085384
# Minibatch accuracy: 60.0%
# VALIDATION accuracy: 62.4%
# Minibatch loss at step 1600: 45.926460
# Minibatch accuracy: 40.0%
# VALIDATION accuracy: 62.4%
# Minibatch loss at step 1700: 42.926418
# Minibatch accuracy: 40.0%
# VALIDATION accuracy: 62.4%
# Minibatch loss at step 1800: 39.854542
# Minibatch accuracy: 60.0%
# VALIDATION accuracy: 62.4%
# Minibatch loss at step 1900: 37.115467
# Minibatch accuracy: 100.0%
# VALIDATION accuracy: 62.4%
# Minibatch loss at step 2000: 34.691376
# Minibatch accuracy: 100.0%
# VALIDATION accuracy: 62.4%
# Minibatch loss at step 2100: 33.515793
# Minibatch accuracy: 20.0%
# VALIDATION accuracy: 62.4%
# Minibatch loss at step 2200: 30.701569
# Minibatch accuracy: 100.0%
# VALIDATION accuracy: 62.4%
# Minibatch loss at step 2300: 29.245100
# Minibatch accuracy: 60.0%
# VALIDATION accuracy: 62.4%
# Minibatch loss at step 2400: 27.417486
# Minibatch accuracy: 80.0%
# VALIDATION accuracy: 62.4%
# Minibatch loss at step 2500: 26.000444
# Minibatch accuracy: 80.0%
# VALIDATION accuracy: 62.4%
# Minibatch loss at step 2600: 24.881134
# Minibatch accuracy: 60.0%
# VALIDATION accuracy: 62.4%
# Minibatch loss at step 2700: 23.508833
# Minibatch accuracy: 60.0%
# VALIDATION accuracy: 62.4%
# Minibatch loss at step 2800: 22.073029
# Minibatch accuracy: 80.0%
# VALIDATION accuracy: 62.4%
# Minibatch loss at step 2900: 21.503168
# Minibatch accuracy: 40.0%
# VALIDATION accuracy: 62.4%
# Minibatch loss at step 3000: 20.295893
# Minibatch accuracy: 60.0%
# VALIDATION accuracy: 62.4%
# Minibatch loss at step 3100: 18.790396
# Minibatch accuracy: 100.0%
# VALIDATION accuracy: 62.4%
# Minibatch loss at step 3200: 18.453484
# Minibatch accuracy: 60.0%
# VALIDATION accuracy: 62.4%
# Minibatch loss at step 3300: 17.219070
# Minibatch accuracy: 100.0%
# VALIDATION accuracy: 62.4%
# Minibatch loss at step 3400: 16.581600
# Minibatch accuracy: 80.0%
# VALIDATION accuracy: 62.4%
# Minibatch loss at step 3500: 15.948419
# Minibatch accuracy: 80.0%
# VALIDATION accuracy: 62.4%
# Minibatch loss at step 3600: 16.039303
# Minibatch accuracy: 20.0%
# VALIDATION accuracy: 62.4%
# Minibatch loss at step 3700: 15.363943
# Minibatch accuracy: 0.0%
# VALIDATION accuracy: 62.4%
# Minibatch loss at step 3800: 14.202532
# Minibatch accuracy: 60.0%
# VALIDATION accuracy: 62.4%
# Minibatch loss at step 3900: 13.353617
# Minibatch accuracy: 100.0%
# VALIDATION accuracy: 62.4%
# Minibatch loss at step 4000: 12.534921
# Minibatch accuracy: 100.0%
# VALIDATION accuracy: 62.4%
# Minibatch loss at step 4100: 13.060983
# Minibatch accuracy: 40.0%
# VALIDATION accuracy: 62.4%
# Minibatch loss at step 4200: 12.332366
# Minibatch accuracy: 40.0%
# VALIDATION accuracy: 62.4%
# Minibatch loss at step 4300: 11.798548
# Minibatch accuracy: 40.0%
# VALIDATION accuracy: 62.4%
# Minibatch loss at step 4400: 11.669274
# Minibatch accuracy: 20.0%
# VALIDATION accuracy: 62.4%
# Minibatch loss at step 4500: 10.508579
# Minibatch accuracy: 100.0%
# VALIDATION accuracy: 62.4%
# Minibatch loss at step 4600: 10.999268
# Minibatch accuracy: 40.0%
# VALIDATION accuracy: 62.4%
# Minibatch loss at step 4700: 10.481158
# Minibatch accuracy: 60.0%
# VALIDATION accuracy: 62.4%
# Minibatch loss at step 4800: 10.246737
# Minibatch accuracy: 40.0%
# VALIDATION accuracy: 62.4%
# Minibatch loss at step 4900: 9.400444
# Minibatch accuracy: 80.0%
# VALIDATION accuracy: 62.4%
# Minibatch loss at step 5000: 9.330966
# Minibatch accuracy: 60.0%
# VALIDATION accuracy: 62.4%
# Minibatch loss at step 5100: 9.364319
# Minibatch accuracy: 40.0%
# VALIDATION accuracy: 62.4%
# Minibatch loss at step 5200: 8.453018
# Minibatch accuracy: 100.0%
# VALIDATION accuracy: 62.4%
# Minibatch loss at step 5300: 8.654645
# Minibatch accuracy: 60.0%
# VALIDATION accuracy: 62.4%
# Minibatch loss at step 5400: 8.551106
# Minibatch accuracy: 40.0%
# VALIDATION accuracy: 62.4%
# Minibatch loss at step 5500: 8.239046
# Minibatch accuracy: 40.0%
# VALIDATION accuracy: 62.4%
# Minibatch loss at step 5600: 7.881921
# Minibatch accuracy: 60.0%
# VALIDATION accuracy: 62.4%
# Minibatch loss at step 5700: 7.720542
# Minibatch accuracy: 80.0%
# VALIDATION accuracy: 62.4%
# Minibatch loss at step 5800: 7.655573
# Minibatch accuracy: 40.0%
# VALIDATION accuracy: 62.4%
# Minibatch loss at step 5900: 6.796388
# Minibatch accuracy: 100.0%
# VALIDATION accuracy: 62.4%
# Minibatch loss at step 6000: 6.748358
# Minibatch accuracy: 100.0%
# VALIDATION accuracy: 62.4%
# Minibatch loss at step 6100: 6.873281
# Minibatch accuracy: 80.0%
# VALIDATION accuracy: 62.4%
# Minibatch loss at step 6200: 6.873775
# Minibatch accuracy: 60.0%
# VALIDATION accuracy: 62.4%
# Minibatch loss at step 6300: 6.873958
# Minibatch accuracy: 40.0%
# VALIDATION accuracy: 62.4%
# Minibatch loss at step 6400: 6.541498
# Minibatch accuracy: 60.0%
# VALIDATION accuracy: 62.4%
# Minibatch loss at step 6500: 6.198173
# Minibatch accuracy: 80.0%
# VALIDATION accuracy: 62.4%
# Minibatch loss at step 6600: 6.012069
# Minibatch accuracy: 100.0%
# VALIDATION accuracy: 62.4%
# Minibatch loss at step 6700: 6.158691
# Minibatch accuracy: 60.0%
# VALIDATION accuracy: 62.4%
# Minibatch loss at step 6800: 5.917267
# Minibatch accuracy: 80.0%
# VALIDATION accuracy: 62.4%
# Minibatch loss at step 6900: 5.901975
# Minibatch accuracy: 60.0%
# VALIDATION accuracy: 62.4%
# Minibatch loss at step 7000: 6.046151
# Minibatch accuracy: 40.0%
# VALIDATION accuracy: 62.4%
# Minibatch loss at step 7100: 5.469552
# Minibatch accuracy: 100.0%
# VALIDATION accuracy: 62.4%
# Minibatch loss at step 7200: 5.818113
# Minibatch accuracy: 40.0%
# VALIDATION accuracy: 62.4%
# Minibatch loss at step 7300: 5.257642
# Minibatch accuracy: 100.0%
# VALIDATION accuracy: 62.4%
# Minibatch loss at step 7400: 5.015014
# Minibatch accuracy: 100.0%
# VALIDATION accuracy: 62.4%
# Minibatch loss at step 7500: 5.275872
# Minibatch accuracy: 80.0%
# VALIDATION accuracy: 62.4%
# Minibatch loss at step 7600: 5.406180
# Minibatch accuracy: 60.0%
# VALIDATION accuracy: 62.4%
# Minibatch loss at step 7700: 5.445485
# Minibatch accuracy: 60.0%
# VALIDATION accuracy: 62.4%
# Minibatch loss at step 7800: 5.120499
# Minibatch accuracy: 60.0%
# VALIDATION accuracy: 62.4%
# Minibatch loss at step 7900: 4.883204
# Minibatch accuracy: 80.0%
# VALIDATION accuracy: 62.4%
# Minibatch loss at step 8000: 5.527376
# Minibatch accuracy: 20.0%
# VALIDATION accuracy: 62.4%
# Minibatch loss at step 8100: 4.691030
# Minibatch accuracy: 80.0%
# VALIDATION accuracy: 62.4%
# Minibatch loss at step 8200: 5.158616
# Minibatch accuracy: 40.0%
# VALIDATION accuracy: 62.4%
# Minibatch loss at step 8300: 4.676540
# Minibatch accuracy: 80.0%
# VALIDATION accuracy: 62.4%
# Minibatch loss at step 8400: 4.790081
# Minibatch accuracy: 60.0%
# VALIDATION accuracy: 62.4%
# Minibatch loss at step 8500: 4.537862
# Minibatch accuracy: 80.0%
# VALIDATION accuracy: 62.4%
# Minibatch loss at step 8600: 5.176647
# Minibatch accuracy: 40.0%
# VALIDATION accuracy: 62.4%
# Minibatch loss at step 8700: 4.676977
# Minibatch accuracy: 60.0%
# VALIDATION accuracy: 62.4%
# Minibatch loss at step 8800: 4.686225
# Minibatch accuracy: 60.0%
# VALIDATION accuracy: 62.4%
# Minibatch loss at step 8900: 4.573467
# Minibatch accuracy: 60.0%
# VALIDATION accuracy: 62.4%
# Minibatch loss at step 9000: 4.404234
# Minibatch accuracy: 60.0%
# VALIDATION accuracy: 62.4%
# Minibatch loss at step 9100: 4.329483
# Minibatch accuracy: 60.0%
# VALIDATION accuracy: 62.4%
# Minibatch loss at step 9200: 4.322887
# Minibatch accuracy: 60.0%
# VALIDATION accuracy: 62.4%
# Minibatch loss at step 9300: 4.526027
# Minibatch accuracy: 40.0%
# VALIDATION accuracy: 62.4%
# Minibatch loss at step 9400: 4.160168
# Minibatch accuracy: 60.0%
# VALIDATION accuracy: 62.4%
# Minibatch loss at step 9500: 4.960588
# Minibatch accuracy: 0.0%
# VALIDATION accuracy: 62.4%
# Minibatch loss at step 9600: 4.553717
# Minibatch accuracy: 40.0%
# VALIDATION accuracy: 62.4%
# Minibatch loss at step 9700: 4.051068
# Minibatch accuracy: 60.0%
# VALIDATION accuracy: 62.4%
# Minibatch loss at step 9800: 4.108508
# Minibatch accuracy: 60.0%
# VALIDATION accuracy: 62.4%
# Minibatch loss at step 9900: 3.549499
# Minibatch accuracy: 100.0%
# VALIDATION accuracy: 62.4%
# Minibatch loss at step 10000: 4.674397
# Minibatch accuracy: 0.0%
# VALIDATION accuracy: 62.4%
# Minibatch loss at step 10100: 3.682386
# Minibatch accuracy: 100.0%
# VALIDATION accuracy: 62.4%
# Minibatch loss at step 10200: 3.793293
# Minibatch accuracy: 80.0%
# VALIDATION accuracy: 62.4%
# Minibatch loss at step 10300: 3.762704
# Minibatch accuracy: 80.0%
# VALIDATION accuracy: 62.4%
# Minibatch loss at step 10400: 3.611170
# Minibatch accuracy: 80.0%
# VALIDATION accuracy: 62.4%
# Minibatch loss at step 10500: 4.530282
# Minibatch accuracy: 20.0%
# VALIDATION accuracy: 62.4%
# Minibatch loss at step 10600: 3.730231
# Minibatch accuracy: 80.0%
# VALIDATION accuracy: 62.4%
# Minibatch loss at step 10700: 3.844977
# Minibatch accuracy: 60.0%
# VALIDATION accuracy: 62.4%
# Minibatch loss at step 10800: 4.120993
# Minibatch accuracy: 20.0%
# VALIDATION accuracy: 62.4%
# Minibatch loss at step 10900: 3.401877
# Minibatch accuracy: 80.0%
# VALIDATION accuracy: 62.4%
# Minibatch loss at step 11000: 4.063670
# Minibatch accuracy: 40.0%
# VALIDATION accuracy: 62.4%
# Minibatch loss at step 11100: 3.457352
# Minibatch accuracy: 80.0%
# VALIDATION accuracy: 62.4%
# Minibatch loss at step 11200: 3.474087
# Minibatch accuracy: 80.0%
# VALIDATION accuracy: 62.4%
# Minibatch loss at step 11300: 3.232100
# Minibatch accuracy: 100.0%
# VALIDATION accuracy: 62.4%
# Minibatch loss at step 11400: 3.657445
# Minibatch accuracy: 60.0%
# VALIDATION accuracy: 62.4%
# Minibatch loss at step 11500: 3.929210
# Minibatch accuracy: 20.0%
# VALIDATION accuracy: 62.4%
# Minibatch loss at step 11600: 3.571542
# Minibatch accuracy: 60.0%
# VALIDATION accuracy: 62.4%
# Minibatch loss at step 11700: 3.675228
# Minibatch accuracy: 60.0%
# VALIDATION accuracy: 62.4%
# Minibatch loss at step 11800: 3.305985
# Minibatch accuracy: 100.0%
# VALIDATION accuracy: 62.4%
# Minibatch loss at step 11900: 3.226821
# Minibatch accuracy: 80.0%
# VALIDATION accuracy: 62.4%
# Minibatch loss at step 12000: 2.893304
# Minibatch accuracy: 100.0%
# VALIDATION accuracy: 62.4%
# Minibatch loss at step 12100: 3.816051
# Minibatch accuracy: 40.0%
# VALIDATION accuracy: 62.4%
# Minibatch loss at step 12200: 3.061491
# Minibatch accuracy: 100.0%
# VALIDATION accuracy: 62.4%
# Minibatch loss at step 12300: 3.256852
# Minibatch accuracy: 60.0%
# VALIDATION accuracy: 62.4%
# Minibatch loss at step 12400: 3.405176
# Minibatch accuracy: 80.0%
# VALIDATION accuracy: 62.4%
# Minibatch loss at step 12500: 2.991373
# Minibatch accuracy: 100.0%
# VALIDATION accuracy: 62.4%
# Minibatch loss at step 12600: 3.085765
# Minibatch accuracy: 80.0%
# VALIDATION accuracy: 62.4%
# Minibatch loss at step 12700: 3.105083
# Minibatch accuracy: 80.0%
# VALIDATION accuracy: 62.4%
# Minibatch loss at step 12800: 3.120020
# Minibatch accuracy: 100.0%
# VALIDATION accuracy: 62.4%
# Minibatch loss at step 12900: 3.577022
# Minibatch accuracy: 40.0%
# VALIDATION accuracy: 62.4%
# Minibatch loss at step 13000: 2.994284
# Minibatch accuracy: 100.0%
# VALIDATION accuracy: 62.4%
# Minibatch loss at step 13100: 3.280265
# Minibatch accuracy: 60.0%
# VALIDATION accuracy: 62.4%
# Minibatch loss at step 13200: 2.986810
# Minibatch accuracy: 80.0%
# VALIDATION accuracy: 62.4%
# Minibatch loss at step 13300: 3.234663
# Minibatch accuracy: 60.0%
# VALIDATION accuracy: 62.4%
# Minibatch loss at step 13400: 3.600496
# Minibatch accuracy: 20.0%
# VALIDATION accuracy: 62.4%
# Minibatch loss at step 13500: 3.112472
# Minibatch accuracy: 80.0%
# VALIDATION accuracy: 62.4%
# Minibatch loss at step 13600: 3.537104
# Minibatch accuracy: 40.0%
# VALIDATION accuracy: 62.4%
# Minibatch loss at step 13700: 3.365549
# Minibatch accuracy: 60.0%
# VALIDATION accuracy: 62.4%
# Minibatch loss at step 13800: 2.960836
# Minibatch accuracy: 80.0%
# VALIDATION accuracy: 62.4%
# Minibatch loss at step 13900: 3.182370
# Minibatch accuracy: 40.0%
# VALIDATION accuracy: 62.4%
# Minibatch loss at step 14000: 3.442073
# Minibatch accuracy: 60.0%
# VALIDATION accuracy: 62.4%
# Minibatch loss at step 14100: 3.626300
# Minibatch accuracy: 60.0%
# VALIDATION accuracy: 62.4%
# Minibatch loss at step 14200: 3.834989
# Minibatch accuracy: 40.0%
# VALIDATION accuracy: 62.4%
# Minibatch loss at step 14300: 2.703626
# Minibatch accuracy: 100.0%
# VALIDATION accuracy: 62.4%
# Minibatch loss at step 14400: 3.469012
# Minibatch accuracy: 60.0%
# VALIDATION accuracy: 62.4%
# Minibatch loss at step 14500: 2.935808
# Minibatch accuracy: 100.0%
# VALIDATION accuracy: 62.4%
# Minibatch loss at step 14600: 2.871483
# Minibatch accuracy: 100.0%
# VALIDATION accuracy: 62.4%
# Minibatch loss at step 14700: 3.120641
# Minibatch accuracy: 60.0%
# VALIDATION accuracy: 62.4%
# Minibatch loss at step 14800: 3.144341
# Minibatch accuracy: 60.0%
# VALIDATION accuracy: 62.4%
# Minibatch loss at step 14900: 2.993865
# Minibatch accuracy: 80.0%
# VALIDATION accuracy: 62.4%
# Minibatch loss at step 15000: 3.579348
# Minibatch accuracy: 40.0%
# VALIDATION accuracy: 62.4%
# Minibatch loss at step 15100: 3.350249
# Minibatch accuracy: 60.0%
# VALIDATION accuracy: 62.4%
# Minibatch loss at step 15200: 3.723172
# Minibatch accuracy: 80.0%
# VALIDATION accuracy: 62.4%
# Minibatch loss at step 15300: 2.641622
# Minibatch accuracy: 80.0%
# VALIDATION accuracy: 62.4%
# Minibatch loss at step 15400: 2.931390
# Minibatch accuracy: 60.0%
# VALIDATION accuracy: 62.4%
# Minibatch loss at step 15500: 2.889318
# Minibatch accuracy: 60.0%
# VALIDATION accuracy: 61.9%
# Minibatch loss at step 15600: 2.702690
# Minibatch accuracy: 100.0%
# VALIDATION accuracy: 62.4%
# Minibatch loss at step 15700: 3.369747
# Minibatch accuracy: 20.0%
# VALIDATION accuracy: 62.4%
# Minibatch loss at step 15800: 2.907416
# Minibatch accuracy: 60.0%
# VALIDATION accuracy: 62.4%
# Minibatch loss at step 15900: 2.708304
# Minibatch accuracy: 80.0%
# VALIDATION accuracy: 67.3%
# Minibatch loss at step 16000: 2.713865
# Minibatch accuracy: 60.0%
# VALIDATION accuracy: 66.7%
# Minibatch loss at step 16100: 3.031617
# Minibatch accuracy: 60.0%
# VALIDATION accuracy: 65.6%
# Minibatch loss at step 16200: 2.774357
# Minibatch accuracy: 80.0%
# VALIDATION accuracy: 66.4%
# Minibatch loss at step 16300: 2.682929
# Minibatch accuracy: 60.0%
# VALIDATION accuracy: 63.1%
# Minibatch loss at step 16400: 3.821418
# Minibatch accuracy: 20.0%
# VALIDATION accuracy: 64.9%
# Minibatch loss at step 16500: 2.539601
# Minibatch accuracy: 100.0%
# VALIDATION accuracy: 67.2%
# Minibatch loss at step 16600: 3.004080
# Minibatch accuracy: 60.0%
# VALIDATION accuracy: 65.3%
# Minibatch loss at step 16700: 3.120802
# Minibatch accuracy: 40.0%
# VALIDATION accuracy: 66.1%
# Minibatch loss at step 16800: 3.445092
# Minibatch accuracy: 20.0%
# VALIDATION accuracy: 68.4%
# Minibatch loss at step 16900: 3.104556
# Minibatch accuracy: 40.0%
# VALIDATION accuracy: 70.9%
# Minibatch loss at step 17000: 2.713239
# Minibatch accuracy: 80.0%
# VALIDATION accuracy: 67.0%
# Minibatch loss at step 17100: 2.810454
# Minibatch accuracy: 80.0%
# VALIDATION accuracy: 66.4%
# Minibatch loss at step 17200: 2.355918
# Minibatch accuracy: 100.0%
# VALIDATION accuracy: 70.8%
# Minibatch loss at step 17300: 2.701945
# Minibatch accuracy: 80.0%
# VALIDATION accuracy: 71.0%
# Minibatch loss at step 17400: 3.088875
# Minibatch accuracy: 80.0%
# VALIDATION accuracy: 69.0%
# Minibatch loss at step 17500: 2.450373
# Minibatch accuracy: 100.0%
# VALIDATION accuracy: 70.6%
# Minibatch loss at step 17600: 2.488263
# Minibatch accuracy: 100.0%
# VALIDATION accuracy: 73.6%
# Minibatch loss at step 17700: 2.850613
# Minibatch accuracy: 80.0%
# VALIDATION accuracy: 71.6%
# Minibatch loss at step 17800: 2.633133
# Minibatch accuracy: 80.0%
# VALIDATION accuracy: 64.8%
# Minibatch loss at step 17900: 2.792914
# Minibatch accuracy: 60.0%
# VALIDATION accuracy: 74.1%
# Minibatch loss at step 18000: 2.748172
# Minibatch accuracy: 80.0%
# VALIDATION accuracy: 74.9%
# Minibatch loss at step 18100: 2.652636
# Minibatch accuracy: 80.0%
# VALIDATION accuracy: 74.6%
# Minibatch loss at step 18200: 2.845836
# Minibatch accuracy: 40.0%
# VALIDATION accuracy: 74.4%
# Minibatch loss at step 18300: 2.802686
# Minibatch accuracy: 60.0%
# VALIDATION accuracy: 74.3%
# Minibatch loss at step 18400: 2.791195
# Minibatch accuracy: 80.0%
# VALIDATION accuracy: 73.2%
# Minibatch loss at step 18500: 2.558636
# Minibatch accuracy: 80.0%
# VALIDATION accuracy: 68.9%
# Minibatch loss at step 18600: 2.343807
# Minibatch accuracy: 100.0%
# VALIDATION accuracy: 74.6%
# Minibatch loss at step 18700: 2.455904
# Minibatch accuracy: 80.0%
# VALIDATION accuracy: 74.5%
# Minibatch loss at step 18800: 2.674467
# Minibatch accuracy: 60.0%
# VALIDATION accuracy: 74.8%
# Minibatch loss at step 18900: 2.719028
# Minibatch accuracy: 80.0%
# VALIDATION accuracy: 73.2%
# Minibatch loss at step 19000: 2.714904
# Minibatch accuracy: 60.0%
# VALIDATION accuracy: 74.9%
# Minibatch loss at step 19100: 2.340915
# Minibatch accuracy: 80.0%
# VALIDATION accuracy: 74.3%
# Minibatch loss at step 19200: 2.358506
# Minibatch accuracy: 80.0%
# VALIDATION accuracy: 74.1%
# Minibatch loss at step 19300: 2.668222
# Minibatch accuracy: 60.0%
# VALIDATION accuracy: 75.5%
# Minibatch loss at step 19400: 2.980797
# Minibatch accuracy: 60.0%
# VALIDATION accuracy: 75.1%
# Minibatch loss at step 19500: 2.825189
# Minibatch accuracy: 60.0%
# VALIDATION accuracy: 73.5%
# Minibatch loss at step 19600: 2.853519
# Minibatch accuracy: 60.0%
# VALIDATION accuracy: 74.2%
# Minibatch loss at step 19700: 2.334003
# Minibatch accuracy: 100.0%
# VALIDATION accuracy: 74.8%
# Minibatch loss at step 19800: 2.540715
# Minibatch accuracy: 60.0%
# VALIDATION accuracy: 73.6%
# Minibatch loss at step 19900: 2.503019
# Minibatch accuracy: 80.0%
# VALIDATION accuracy: 75.1%
# Minibatch loss at step 20000: 2.729236
# Minibatch accuracy: 80.0%
# VALIDATION accuracy: 74.1%
# Minibatch loss at step 20100: 2.339733
# Minibatch accuracy: 100.0%
# VALIDATION accuracy: 75.3%
# Minibatch loss at step 20200: 3.070279
# Minibatch accuracy: 60.0%
# VALIDATION accuracy: 74.3%
# Minibatch loss at step 20300: 2.840994
# Minibatch accuracy: 60.0%
# VALIDATION accuracy: 72.5%
# Minibatch loss at step 20400: 2.653375
# Minibatch accuracy: 60.0%
# VALIDATION accuracy: 75.6%
# Minibatch loss at step 20500: 2.673153
# Minibatch accuracy: 100.0%
# VALIDATION accuracy: 71.8%
# Minibatch loss at step 20600: 2.401726
# Minibatch accuracy: 100.0%
# VALIDATION accuracy: 73.8%
# Minibatch loss at step 20700: 2.922080
# Minibatch accuracy: 80.0%
# VALIDATION accuracy: 74.5%
# Minibatch loss at step 20800: 2.472166
# Minibatch accuracy: 80.0%
# VALIDATION accuracy: 74.7%
# Minibatch loss at step 20900: 2.600628
# Minibatch accuracy: 60.0%
# VALIDATION accuracy: 76.0%
# Minibatch loss at step 21000: 2.837983
# Minibatch accuracy: 60.0%
# VALIDATION accuracy: 75.1%
# Minibatch loss at step 21100: 2.483623
# Minibatch accuracy: 80.0%
# VALIDATION accuracy: 75.7%
# Minibatch loss at step 21200: 2.990280
# Minibatch accuracy: 60.0%
# VALIDATION accuracy: 75.8%
# Minibatch loss at step 21300: 2.408828
# Minibatch accuracy: 80.0%
# VALIDATION accuracy: 76.1%
# Minibatch loss at step 21400: 2.299620
# Minibatch accuracy: 100.0%
# VALIDATION accuracy: 75.9%
# Minibatch loss at step 21500: 3.349458
# Minibatch accuracy: 40.0%
# VALIDATION accuracy: 76.0%
# Minibatch loss at step 21600: 3.928524
# Minibatch accuracy: 40.0%
# VALIDATION accuracy: 76.0%
# Minibatch loss at step 21700: 2.271035
# Minibatch accuracy: 100.0%
# VALIDATION accuracy: 76.3%
# Minibatch loss at step 21800: 2.656940
# Minibatch accuracy: 60.0%
# VALIDATION accuracy: 75.3%
# Minibatch loss at step 21900: 3.217200
# Minibatch accuracy: 40.0%
# VALIDATION accuracy: 74.1%
# Minibatch loss at step 22000: 3.219960
# Minibatch accuracy: 60.0%
# VALIDATION accuracy: 75.5%
# Minibatch loss at step 22100: 2.797642
# Minibatch accuracy: 80.0%
# VALIDATION accuracy: 77.3%
# Minibatch loss at step 22200: 3.134911
# Minibatch accuracy: 60.0%
# VALIDATION accuracy: 75.8%
# Minibatch loss at step 22300: 2.503782
# Minibatch accuracy: 80.0%
# VALIDATION accuracy: 75.5%
# Minibatch loss at step 22400: 2.223591
# Minibatch accuracy: 100.0%
# VALIDATION accuracy: 75.7%
# Minibatch loss at step 22500: 2.323244
# Minibatch accuracy: 80.0%
# VALIDATION accuracy: 76.9%
# Minibatch loss at step 22600: 2.958036
# Minibatch accuracy: 80.0%
# VALIDATION accuracy: 75.1%
# Minibatch loss at step 22700: 2.328369
# Minibatch accuracy: 100.0%
# VALIDATION accuracy: 75.8%
# Minibatch loss at step 22800: 2.785234
# Minibatch accuracy: 60.0%
# VALIDATION accuracy: 74.0%
# Minibatch loss at step 22900: 2.845789
# Minibatch accuracy: 60.0%
# VALIDATION accuracy: 75.8%
# Minibatch loss at step 23000: 2.774719
# Minibatch accuracy: 80.0%
# VALIDATION accuracy: 75.2%
# Minibatch loss at step 23100: 2.619641
# Minibatch accuracy: 60.0%
# VALIDATION accuracy: 76.1%
# Minibatch loss at step 23200: 2.539291
# Minibatch accuracy: 80.0%
# VALIDATION accuracy: 76.3%
# Minibatch loss at step 23300: 2.567384
# Minibatch accuracy: 80.0%
# VALIDATION accuracy: 74.8%
# Minibatch loss at step 23400: 2.315773
# Minibatch accuracy: 100.0%
# VALIDATION accuracy: 76.2%
# Minibatch loss at step 23500: 2.806282
# Minibatch accuracy: 80.0%
# VALIDATION accuracy: 76.2%
# Minibatch loss at step 23600: 2.909731
# Minibatch accuracy: 80.0%
# VALIDATION accuracy: 75.9%
# Minibatch loss at step 23700: 2.972309
# Minibatch accuracy: 60.0%
# VALIDATION accuracy: 76.5%
# Minibatch loss at step 23800: 2.497323
# Minibatch accuracy: 80.0%
# VALIDATION accuracy: 76.5%
# Minibatch loss at step 23900: 2.618773
# Minibatch accuracy: 60.0%
# VALIDATION accuracy: 76.8%
# Minibatch loss at step 24000: 3.270138
# Minibatch accuracy: 60.0%
# VALIDATION accuracy: 75.7%
# Minibatch loss at step 24100: 2.321983
# Minibatch accuracy: 80.0%
# VALIDATION accuracy: 75.8%
# Minibatch loss at step 24200: 2.649767
# Minibatch accuracy: 60.0%
# VALIDATION accuracy: 75.5%
# Minibatch loss at step 24300: 2.271882
# Minibatch accuracy: 80.0%
# VALIDATION accuracy: 76.7%
# Minibatch loss at step 24400: 2.591877
# Minibatch accuracy: 80.0%
# VALIDATION accuracy: 76.3%
# Minibatch loss at step 24500: 2.425331
# Minibatch accuracy: 80.0%
# VALIDATION accuracy: 76.5%
# Minibatch loss at step 24600: 2.194304
# Minibatch accuracy: 100.0%
# VALIDATION accuracy: 76.5%
# Minibatch loss at step 24700: 3.087537
# Minibatch accuracy: 60.0%
# VALIDATION accuracy: 75.3%
# Minibatch loss at step 24800: 2.269774
# Minibatch accuracy: 100.0%
# VALIDATION accuracy: 76.9%
# Minibatch loss at step 24900: 2.446094
# Minibatch accuracy: 80.0%
# VALIDATION accuracy: 75.8%
# Minibatch loss at step 25000: 2.527707
# Minibatch accuracy: 80.0%
# VALIDATION accuracy: 75.5%
# Minibatch loss at step 25100: 2.378777
# Minibatch accuracy: 60.0%
# VALIDATION accuracy: 75.8%
# Minibatch loss at step 25200: 2.762988
# Minibatch accuracy: 60.0%
# VALIDATION accuracy: 75.1%
# Minibatch loss at step 25300: 2.758650
# Minibatch accuracy: 60.0%
# VALIDATION accuracy: 75.6%
# Minibatch loss at step 25400: 2.553271
# Minibatch accuracy: 80.0%
# VALIDATION accuracy: 76.9%
# Minibatch loss at step 25500: 2.241579
# Minibatch accuracy: 100.0%
# VALIDATION accuracy: 77.2%
# Minibatch loss at step 25600: 2.173899
# Minibatch accuracy: 100.0%
# VALIDATION accuracy: 75.7%
# Minibatch loss at step 25700: 2.653034
# Minibatch accuracy: 80.0%
# VALIDATION accuracy: 75.8%
# Minibatch loss at step 25800: 2.636796
# Minibatch accuracy: 60.0%
# VALIDATION accuracy: 75.8%
# Minibatch loss at step 25900: 2.829318
# Minibatch accuracy: 80.0%
# VALIDATION accuracy: 75.9%
# Minibatch loss at step 26000: 2.700100
# Minibatch accuracy: 60.0%
# VALIDATION accuracy: 76.7%
# Minibatch loss at step 26100: 2.302379
# Minibatch accuracy: 80.0%
# VALIDATION accuracy: 76.8%
# Minibatch loss at step 26200: 2.698780
# Minibatch accuracy: 60.0%
# VALIDATION accuracy: 76.6%
# Minibatch loss at step 26300: 2.503410
# Minibatch accuracy: 80.0%
# VALIDATION accuracy: 76.3%
# Minibatch loss at step 26400: 2.355279
# Minibatch accuracy: 100.0%
# VALIDATION accuracy: 75.6%
# Minibatch loss at step 26500: 2.427952
# Minibatch accuracy: 80.0%
# VALIDATION accuracy: 76.6%
# Minibatch loss at step 26600: 2.275522
# Minibatch accuracy: 100.0%
# VALIDATION accuracy: 77.5%
# Minibatch loss at step 26700: 2.809407
# Minibatch accuracy: 60.0%
# VALIDATION accuracy: 76.1%
# Minibatch loss at step 26800: 2.200035
# Minibatch accuracy: 100.0%
# VALIDATION accuracy: 76.3%
# Minibatch loss at step 26900: 2.787425
# Minibatch accuracy: 60.0%
# VALIDATION accuracy: 77.0%
# Minibatch loss at step 27000: 2.351957
# Minibatch accuracy: 80.0%
# VALIDATION accuracy: 77.0%
# Minibatch loss at step 27100: 2.709135
# Minibatch accuracy: 80.0%
# VALIDATION accuracy: 75.8%
# Minibatch loss at step 27200: 2.369809
# Minibatch accuracy: 80.0%
# VALIDATION accuracy: 76.6%
# Minibatch loss at step 27300: 2.451474
# Minibatch accuracy: 60.0%
# VALIDATION accuracy: 75.7%
# Minibatch loss at step 27400: 2.406411
# Minibatch accuracy: 80.0%
# VALIDATION accuracy: 77.2%
# Minibatch loss at step 27500: 2.249421
# Minibatch accuracy: 100.0%
# VALIDATION accuracy: 76.3%
# Minibatch loss at step 27600: 2.977854
# Minibatch accuracy: 60.0%
# VALIDATION accuracy: 76.6%
# Minibatch loss at step 27700: 2.243472
# Minibatch accuracy: 100.0%
# VALIDATION accuracy: 77.0%
# Minibatch loss at step 27800: 2.328979
# Minibatch accuracy: 80.0%
# VALIDATION accuracy: 76.8%
# Minibatch loss at step 27900: 2.850182
# Minibatch accuracy: 60.0%
# VALIDATION accuracy: 76.8%
# Minibatch loss at step 28000: 2.327267
# Minibatch accuracy: 80.0%
# VALIDATION accuracy: 77.0%
# Minibatch loss at step 28100: 2.504506
# Minibatch accuracy: 60.0%
# VALIDATION accuracy: 76.6%
# Minibatch loss at step 28200: 2.221505
# Minibatch accuracy: 100.0%
# VALIDATION accuracy: 76.8%
# Minibatch loss at step 28300: 2.322741
# Minibatch accuracy: 100.0%
# VALIDATION accuracy: 77.5%
# Minibatch loss at step 28400: 2.275095
# Minibatch accuracy: 100.0%
# VALIDATION accuracy: 76.2%
# Minibatch loss at step 28500: 2.944740
# Minibatch accuracy: 80.0%
# VALIDATION accuracy: 76.2%
# Minibatch loss at step 28600: 2.696706
# Minibatch accuracy: 80.0%
# VALIDATION accuracy: 76.0%
# Minibatch loss at step 28700: 2.212500
# Minibatch accuracy: 100.0%
# VALIDATION accuracy: 76.9%
# Minibatch loss at step 28800: 3.810679
# Minibatch accuracy: 60.0%
# VALIDATION accuracy: 76.7%
# Minibatch loss at step 28900: 2.343005
# Minibatch accuracy: 80.0%
# VALIDATION accuracy: 76.6%
# Minibatch loss at step 29000: 2.566377
# Minibatch accuracy: 60.0%
# VALIDATION accuracy: 77.0%
# Minibatch loss at step 29100: 3.813632
# Minibatch accuracy: 20.0%
# VALIDATION accuracy: 76.1%
# Minibatch loss at step 29200: 2.357091
# Minibatch accuracy: 80.0%
# VALIDATION accuracy: 76.9%
# Minibatch loss at step 29300: 2.199207
# Minibatch accuracy: 100.0%
# VALIDATION accuracy: 77.2%
# Minibatch loss at step 29400: 2.192701
# Minibatch accuracy: 100.0%
# VALIDATION accuracy: 75.9%
# Minibatch loss at step 29500: 2.874883
# Minibatch accuracy: 40.0%
# VALIDATION accuracy: 75.2%
# Minibatch loss at step 29600: 2.181047
# Minibatch accuracy: 100.0%
# VALIDATION accuracy: 76.5%
# Minibatch loss at step 29700: 2.461281
# Minibatch accuracy: 80.0%
# VALIDATION accuracy: 76.5%
# Minibatch loss at step 29800: 2.397391
# Minibatch accuracy: 80.0%
# VALIDATION accuracy: 76.8%
# Minibatch loss at step 29900: 2.128695
# Minibatch accuracy: 100.0%
# VALIDATION accuracy: 77.0%
# Minibatch loss at step 30000: 2.848431
# Minibatch accuracy: 60.0%
# VALIDATION accuracy: 77.4%
# Minibatch loss at step 30100: 2.611246
# Minibatch accuracy: 80.0%
# VALIDATION accuracy: 76.8%
# Minibatch loss at step 30200: 2.566042
# Minibatch accuracy: 80.0%
# VALIDATION accuracy: 77.2%
# Minibatch loss at step 30300: 2.276355
# Minibatch accuracy: 100.0%
# VALIDATION accuracy: 76.8%
# Minibatch loss at step 30400: 2.415212
# Minibatch accuracy: 80.0%
# VALIDATION accuracy: 76.8%
# Minibatch loss at step 30500: 2.528062
# Minibatch accuracy: 60.0%
# VALIDATION accuracy: 77.1%
# Minibatch loss at step 30600: 2.733922
# Minibatch accuracy: 80.0%
# VALIDATION accuracy: 77.0%
# Minibatch loss at step 30700: 2.909129
# Minibatch accuracy: 60.0%
# VALIDATION accuracy: 76.3%
# Minibatch loss at step 30800: 2.249132
# Minibatch accuracy: 100.0%
# VALIDATION accuracy: 76.7%
# Minibatch loss at step 30900: 2.777642
# Minibatch accuracy: 60.0%
# VALIDATION accuracy: 76.0%
# Minibatch loss at step 31000: 2.224754
# Minibatch accuracy: 100.0%
# VALIDATION accuracy: 76.6%
# Minibatch loss at step 31100: 2.280571
# Minibatch accuracy: 100.0%
# VALIDATION accuracy: 77.0%
# Minibatch loss at step 31200: 2.281015
# Minibatch accuracy: 80.0%
# VALIDATION accuracy: 77.0%
# Minibatch loss at step 31300: 2.440215
# Minibatch accuracy: 80.0%
# VALIDATION accuracy: 77.0%
# Minibatch loss at step 31400: 2.260133
# Minibatch accuracy: 80.0%
# VALIDATION accuracy: 76.6%
# Minibatch loss at step 31500: 2.177136
# Minibatch accuracy: 100.0%
# VALIDATION accuracy: 77.0%
# Minibatch loss at step 31600: 2.185256
# Minibatch accuracy: 100.0%
# VALIDATION accuracy: 76.3%
# Minibatch loss at step 31700: 2.639314
# Minibatch accuracy: 80.0%
# VALIDATION accuracy: 76.4%
# Minibatch loss at step 31800: 2.471735
# Minibatch accuracy: 100.0%
# VALIDATION accuracy: 75.2%
# Minibatch loss at step 31900: 2.209817
# Minibatch accuracy: 100.0%
# VALIDATION accuracy: 76.8%
# Minibatch loss at step 32000: 2.327955
# Minibatch accuracy: 80.0%
# VALIDATION accuracy: 76.5%
# Minibatch loss at step 32100: 3.116901
# Minibatch accuracy: 40.0%
# VALIDATION accuracy: 77.3%
# Minibatch loss at step 32200: 2.942064
# Minibatch accuracy: 80.0%
# VALIDATION accuracy: 77.4%
# Minibatch loss at step 32300: 2.459149
# Minibatch accuracy: 80.0%
# VALIDATION accuracy: 77.3%
# Minibatch loss at step 32400: 2.417299
# Minibatch accuracy: 80.0%
# VALIDATION accuracy: 77.0%
# Minibatch loss at step 32500: 2.689539
# Minibatch accuracy: 60.0%
# VALIDATION accuracy: 76.8%
# Minibatch loss at step 32600: 2.587003
# Minibatch accuracy: 80.0%
# VALIDATION accuracy: 76.6%
# Minibatch loss at step 32700: 3.077116
# Minibatch accuracy: 80.0%
# VALIDATION accuracy: 76.9%
# Minibatch loss at step 32800: 2.355592
# Minibatch accuracy: 100.0%
# VALIDATION accuracy: 77.3%
# Minibatch loss at step 32900: 2.121607
# Minibatch accuracy: 100.0%
# VALIDATION accuracy: 77.0%
# Minibatch loss at step 33000: 2.477218
# Minibatch accuracy: 80.0%
# VALIDATION accuracy: 76.8%
# Minibatch loss at step 33100: 3.028875
# Minibatch accuracy: 40.0%
# VALIDATION accuracy: 76.3%
# Minibatch loss at step 33200: 2.459502
# Minibatch accuracy: 80.0%
# VALIDATION accuracy: 77.0%
# Minibatch loss at step 33300: 2.245937
# Minibatch accuracy: 100.0%
# VALIDATION accuracy: 76.8%
# Minibatch loss at step 33400: 2.201066
# Minibatch accuracy: 100.0%
# VALIDATION accuracy: 76.9%
# Minibatch loss at step 33500: 2.215017
# Minibatch accuracy: 100.0%
# VALIDATION accuracy: 77.3%
# Minibatch loss at step 33600: 2.701518
# Minibatch accuracy: 60.0%
# VALIDATION accuracy: 76.6%
# Minibatch loss at step 33700: 2.595407
# Minibatch accuracy: 60.0%
# VALIDATION accuracy: 77.4%
# Minibatch loss at step 33800: 2.551679
# Minibatch accuracy: 80.0%
# VALIDATION accuracy: 76.6%
# Minibatch loss at step 33900: 2.213953
# Minibatch accuracy: 100.0%
# VALIDATION accuracy: 76.7%
# Minibatch loss at step 34000: 2.568618
# Minibatch accuracy: 80.0%
# VALIDATION accuracy: 76.8%
# Minibatch loss at step 34100: 2.362494
# Minibatch accuracy: 100.0%
# VALIDATION accuracy: 76.2%
# Minibatch loss at step 34200: 2.111439
# Minibatch accuracy: 100.0%
# VALIDATION accuracy: 76.1%
# Minibatch loss at step 34300: 2.453007
# Minibatch accuracy: 80.0%
# VALIDATION accuracy: 76.6%
# Minibatch loss at step 34400: 2.369663
# Minibatch accuracy: 80.0%
# VALIDATION accuracy: 77.3%
# Minibatch loss at step 34500: 2.332589
# Minibatch accuracy: 80.0%
# VALIDATION accuracy: 77.4%
# Minibatch loss at step 34600: 2.194486
# Minibatch accuracy: 80.0%
# VALIDATION accuracy: 77.3%
# Minibatch loss at step 34700: 2.288421
# Minibatch accuracy: 80.0%
# VALIDATION accuracy: 77.2%
# Minibatch loss at step 34800: 2.248990
# Minibatch accuracy: 100.0%
# VALIDATION accuracy: 76.9%
# Minibatch loss at step 34900: 2.162731
# Minibatch accuracy: 100.0%
# VALIDATION accuracy: 76.6%
# Minibatch loss at step 35000: 2.190357
# Minibatch accuracy: 100.0%
# VALIDATION accuracy: 77.5%
# Minibatch loss at step 35100: 2.263835
# Minibatch accuracy: 100.0%
# VALIDATION accuracy: 77.3%
# Minibatch loss at step 35200: 2.433900
# Minibatch accuracy: 60.0%
# VALIDATION accuracy: 76.9%
# Minibatch loss at step 35300: 2.441532
# Minibatch accuracy: 60.0%
# VALIDATION accuracy: 76.9%
# Minibatch loss at step 35400: 2.361605
# Minibatch accuracy: 80.0%
# VALIDATION accuracy: 76.3%
# Minibatch loss at step 35500: 2.315253
# Minibatch accuracy: 80.0%
# VALIDATION accuracy: 76.8%
# Minibatch loss at step 35600: 2.403939
# Minibatch accuracy: 80.0%
# VALIDATION accuracy: 76.9%
# Minibatch loss at step 35700: 2.668710
# Minibatch accuracy: 60.0%
# VALIDATION accuracy: 77.0%
# Minibatch loss at step 35800: 2.719398
# Minibatch accuracy: 60.0%
# VALIDATION accuracy: 77.0%
# Minibatch loss at step 35900: 2.442187
# Minibatch accuracy: 80.0%
# VALIDATION accuracy: 76.7%
# Minibatch loss at step 36000: 2.634877
# Minibatch accuracy: 80.0%
# VALIDATION accuracy: 77.0%
# Minibatch loss at step 36100: 3.020853
# Minibatch accuracy: 40.0%
# VALIDATION accuracy: 76.8%
# Minibatch loss at step 36200: 2.390536
# Minibatch accuracy: 80.0%
# VALIDATION accuracy: 77.0%
# Minibatch loss at step 36300: 2.201642
# Minibatch accuracy: 100.0%
# VALIDATION accuracy: 76.1%
# Minibatch loss at step 36400: 2.413030
# Minibatch accuracy: 80.0%
# VALIDATION accuracy: 76.6%
# Minibatch loss at step 36500: 2.442084
# Minibatch accuracy: 80.0%
# VALIDATION accuracy: 76.8%
# Minibatch loss at step 36600: 3.063913
# Minibatch accuracy: 60.0%
# VALIDATION accuracy: 76.8%
# Minibatch loss at step 36700: 2.773843
# Minibatch accuracy: 40.0%
# VALIDATION accuracy: 77.3%
# Minibatch loss at step 36800: 2.850498
# Minibatch accuracy: 60.0%
# VALIDATION accuracy: 77.0%
# Minibatch loss at step 36900: 2.224509
# Minibatch accuracy: 80.0%
# VALIDATION accuracy: 77.2%
# Minibatch loss at step 37000: 2.467251
# Minibatch accuracy: 100.0%
# VALIDATION accuracy: 77.0%
# Minibatch loss at step 37100: 2.281443
# Minibatch accuracy: 80.0%
# VALIDATION accuracy: 76.8%
# Minibatch loss at step 37200: 2.413277
# Minibatch accuracy: 80.0%
# VALIDATION accuracy: 77.4%
# Minibatch loss at step 37300: 2.242262
# Minibatch accuracy: 100.0%
# VALIDATION accuracy: 77.3%
# Minibatch loss at step 37400: 2.402968
# Minibatch accuracy: 80.0%
# VALIDATION accuracy: 77.0%
# Minibatch loss at step 37500: 2.347919
# Minibatch accuracy: 80.0%
# VALIDATION accuracy: 77.0%
# Minibatch loss at step 37600: 2.907473
# Minibatch accuracy: 80.0%
# VALIDATION accuracy: 76.5%
# Minibatch loss at step 37700: 3.124430
# Minibatch accuracy: 60.0%
# VALIDATION accuracy: 76.8%
# Minibatch loss at step 37800: 2.421339
# Minibatch accuracy: 80.0%
# VALIDATION accuracy: 77.0%
# Minibatch loss at step 37900: 2.430983
# Minibatch accuracy: 80.0%
# VALIDATION accuracy: 76.8%
# Minibatch loss at step 38000: 2.852109
# Minibatch accuracy: 60.0%
# VALIDATION accuracy: 77.0%
# Minibatch loss at step 38100: 2.745010
# Minibatch accuracy: 80.0%
# VALIDATION accuracy: 77.0%
# Minibatch loss at step 38200: 2.445919
# Minibatch accuracy: 80.0%
# VALIDATION accuracy: 76.9%
# Minibatch loss at step 38300: 2.525951
# Minibatch accuracy: 80.0%
# VALIDATION accuracy: 76.8%
# Minibatch loss at step 38400: 2.320639
# Minibatch accuracy: 80.0%
# VALIDATION accuracy: 77.0%
# Minibatch loss at step 38500: 2.740470
# Minibatch accuracy: 80.0%
# VALIDATION accuracy: 76.6%
# Minibatch loss at step 38600: 2.784046
# Minibatch accuracy: 40.0%
# VALIDATION accuracy: 76.8%
# Minibatch loss at step 38700: 2.430827
# Minibatch accuracy: 80.0%
# VALIDATION accuracy: 76.8%
# Minibatch loss at step 38800: 2.236765
# Minibatch accuracy: 100.0%
# VALIDATION accuracy: 76.8%
# Minibatch loss at step 38900: 2.313709
# Minibatch accuracy: 80.0%
# VALIDATION accuracy: 76.8%
# Minibatch loss at step 39000: 3.139854
# Minibatch accuracy: 80.0%
# VALIDATION accuracy: 77.3%
# Minibatch loss at step 39100: 2.427071
# Minibatch accuracy: 80.0%
# VALIDATION accuracy: 77.0%
# Minibatch loss at step 39200: 2.449743
# Minibatch accuracy: 80.0%
# VALIDATION accuracy: 77.1%
# Minibatch loss at step 39300: 2.130472
# Minibatch accuracy: 100.0%
# VALIDATION accuracy: 77.0%
# Minibatch loss at step 39400: 2.104485
# Minibatch accuracy: 100.0%
# VALIDATION accuracy: 76.9%
# Minibatch loss at step 39500: 2.607472
# Minibatch accuracy: 80.0%
# VALIDATION accuracy: 77.0%
# Minibatch loss at step 39600: 2.778754
# Minibatch accuracy: 60.0%
# VALIDATION accuracy: 77.3%
# Minibatch loss at step 39700: 2.225288
# Minibatch accuracy: 100.0%
# VALIDATION accuracy: 77.1%
# Minibatch loss at step 39800: 2.471352
# Minibatch accuracy: 80.0%
# VALIDATION accuracy: 76.9%
# Minibatch loss at step 39900: 2.213282
# Minibatch accuracy: 100.0%
# VALIDATION accuracy: 76.8%
# Minibatch loss at step 40000: 2.508749
# Minibatch accuracy: 60.0%
# VALIDATION accuracy: 76.9%
# Minibatch loss at step 40100: 2.279479
# Minibatch accuracy: 100.0%
# VALIDATION accuracy: 77.0%
# Minibatch loss at step 40200: 2.702485
# Minibatch accuracy: 40.0%
# VALIDATION accuracy: 77.0%
# Minibatch loss at step 40300: 2.798138
# Minibatch accuracy: 60.0%
# VALIDATION accuracy: 76.9%
# Minibatch loss at step 40400: 2.340953
# Minibatch accuracy: 100.0%
# VALIDATION accuracy: 76.8%
# Minibatch loss at step 40500: 2.154087
# Minibatch accuracy: 100.0%
# VALIDATION accuracy: 76.9%
# Minibatch loss at step 40600: 2.143831
# Minibatch accuracy: 100.0%
# VALIDATION accuracy: 76.9%
# Minibatch loss at step 40700: 2.527881
# Minibatch accuracy: 80.0%
# VALIDATION accuracy: 76.8%
# Minibatch loss at step 40800: 2.505719
# Minibatch accuracy: 80.0%
# VALIDATION accuracy: 76.7%
# Minibatch loss at step 40900: 2.796185
# Minibatch accuracy: 60.0%
# VALIDATION accuracy: 76.8%
# Minibatch loss at step 41000: 2.397958
# Minibatch accuracy: 80.0%
# VALIDATION accuracy: 76.8%
# Minibatch loss at step 41100: 2.353617
# Minibatch accuracy: 100.0%
# VALIDATION accuracy: 76.8%
# Minibatch loss at step 41200: 2.585774
# Minibatch accuracy: 80.0%
# VALIDATION accuracy: 76.8%
# Minibatch loss at step 41300: 2.301859
# Minibatch accuracy: 100.0%
# VALIDATION accuracy: 76.8%
# Minibatch loss at step 41400: 2.511525
# Minibatch accuracy: 80.0%
# VALIDATION accuracy: 76.9%
# Minibatch loss at step 41500: 2.202620
# Minibatch accuracy: 80.0%
# VALIDATION accuracy: 76.8%
# Minibatch loss at step 41600: 2.301530
# Minibatch accuracy: 100.0%
# VALIDATION accuracy: 76.8%
# Minibatch loss at step 41700: 2.662501
# Minibatch accuracy: 80.0%
# VALIDATION accuracy: 77.0%
# Minibatch loss at step 41800: 2.244104
# Minibatch accuracy: 100.0%
# VALIDATION accuracy: 77.3%
# Minibatch loss at step 41900: 2.780869
# Minibatch accuracy: 40.0%
# VALIDATION accuracy: 77.0%
# Minibatch loss at step 42000: 2.314794
# Minibatch accuracy: 80.0%
# VALIDATION accuracy: 77.0%
# Minibatch loss at step 42100: 2.485669
# Minibatch accuracy: 80.0%
# VALIDATION accuracy: 76.7%
# Minibatch loss at step 42200: 2.204680
# Minibatch accuracy: 100.0%
# VALIDATION accuracy: 76.8%
# Minibatch loss at step 42300: 2.593811
# Minibatch accuracy: 80.0%
# VALIDATION accuracy: 77.0%
# Minibatch loss at step 42400: 2.048796
# Minibatch accuracy: 100.0%
# VALIDATION accuracy: 77.0%
# Minibatch loss at step 42500: 2.398108
# Minibatch accuracy: 80.0%
# VALIDATION accuracy: 77.0%
# Minibatch loss at step 42600: 2.417691
# Minibatch accuracy: 60.0%
# VALIDATION accuracy: 76.8%
# Minibatch loss at step 42700: 2.272930
# Minibatch accuracy: 100.0%
# VALIDATION accuracy: 77.0%
# Minibatch loss at step 42800: 2.497746
# Minibatch accuracy: 80.0%
# VALIDATION accuracy: 76.8%
# Minibatch loss at step 42900: 2.751451
# Minibatch accuracy: 60.0%
# VALIDATION accuracy: 76.8%
# Minibatch loss at step 43000: 3.134902
# Minibatch accuracy: 60.0%
# VALIDATION accuracy: 76.8%
# Minibatch loss at step 43100: 2.848931
# Minibatch accuracy: 60.0%
# VALIDATION accuracy: 76.8%
# Minibatch loss at step 43200: 2.117680
# Minibatch accuracy: 100.0%
# VALIDATION accuracy: 76.9%
# Minibatch loss at step 43300: 2.444485
# Minibatch accuracy: 60.0%
# VALIDATION accuracy: 76.8%
# Minibatch loss at step 43400: 2.171749
# Minibatch accuracy: 100.0%
# VALIDATION accuracy: 76.8%
# Minibatch loss at step 43500: 2.304809
# Minibatch accuracy: 80.0%
# VALIDATION accuracy: 76.8%
# Minibatch loss at step 43600: 2.341920
# Minibatch accuracy: 80.0%
# VALIDATION accuracy: 76.8%
# Minibatch loss at step 43700: 2.148646
# Minibatch accuracy: 100.0%
# VALIDATION accuracy: 76.8%
# Minibatch loss at step 43800: 2.813043
# Minibatch accuracy: 60.0%
# VALIDATION accuracy: 76.8%
# Minibatch loss at step 43900: 2.564592
# Minibatch accuracy: 80.0%
# VALIDATION accuracy: 76.8%
# Minibatch loss at step 44000: 3.080119
# Minibatch accuracy: 60.0%
# VALIDATION accuracy: 76.9%
# Minibatch loss at step 44100: 2.706354
# Minibatch accuracy: 60.0%
# VALIDATION accuracy: 77.0%
# Minibatch loss at step 44200: 2.682158
# Minibatch accuracy: 80.0%
# VALIDATION accuracy: 77.0%
# Minibatch loss at step 44300: 3.036303
# Minibatch accuracy: 60.0%
# VALIDATION accuracy: 77.0%
# Minibatch loss at step 44400: 2.622315
# Minibatch accuracy: 60.0%
# VALIDATION accuracy: 76.8%
# Minibatch loss at step 44500: 2.811192
# Minibatch accuracy: 60.0%
# VALIDATION accuracy: 77.0%
# Minibatch loss at step 44600: 2.424870
# Minibatch accuracy: 80.0%
# VALIDATION accuracy: 77.0%
# Minibatch loss at step 44700: 2.808159
# Minibatch accuracy: 60.0%
# VALIDATION accuracy: 77.0%
# Minibatch loss at step 44800: 2.384000
# Minibatch accuracy: 80.0%
# VALIDATION accuracy: 76.9%
# Minibatch loss at step 44900: 2.265202
# Minibatch accuracy: 100.0%
# VALIDATION accuracy: 77.0%
# Minibatch loss at step 45000: 3.150811
# Minibatch accuracy: 40.0%
# VALIDATION accuracy: 76.9%
# Minibatch loss at step 45100: 2.281204
# Minibatch accuracy: 80.0%
# VALIDATION accuracy: 76.8%
# Minibatch loss at step 45200: 2.448101
# Minibatch accuracy: 80.0%
# VALIDATION accuracy: 76.8%
# Minibatch loss at step 45300: 2.460178
# Minibatch accuracy: 80.0%
# VALIDATION accuracy: 76.8%
# Minibatch loss at step 45400: 2.783741
# Minibatch accuracy: 60.0%
# VALIDATION accuracy: 76.8%
# Minibatch loss at step 45500: 2.852078
# Minibatch accuracy: 80.0%
# VALIDATION accuracy: 76.8%
# Minibatch loss at step 45600: 2.519608
# Minibatch accuracy: 60.0%
# VALIDATION accuracy: 76.8%
# Minibatch loss at step 45700: 2.374427
# Minibatch accuracy: 80.0%
# VALIDATION accuracy: 76.8%
# Minibatch loss at step 45800: 2.377931
# Minibatch accuracy: 80.0%
# VALIDATION accuracy: 76.8%
# Minibatch loss at step 45900: 2.411311
# Minibatch accuracy: 80.0%
# VALIDATION accuracy: 76.8%
# Minibatch loss at step 46000: 2.298108
# Minibatch accuracy: 80.0%
# VALIDATION accuracy: 76.8%
# Minibatch loss at step 46100: 2.634132
# Minibatch accuracy: 60.0%
# VALIDATION accuracy: 76.8%
# Minibatch loss at step 46200: 2.363560
# Minibatch accuracy: 80.0%
# VALIDATION accuracy: 76.8%
# Minibatch loss at step 46300: 2.772506
# Minibatch accuracy: 60.0%
# VALIDATION accuracy: 76.9%
# Minibatch loss at step 46400: 2.388815
# Minibatch accuracy: 80.0%
# VALIDATION accuracy: 77.0%
# Minibatch loss at step 46500: 2.288849
# Minibatch accuracy: 100.0%
# VALIDATION accuracy: 77.0%
# Minibatch loss at step 46600: 2.702908
# Minibatch accuracy: 80.0%
# VALIDATION accuracy: 76.9%
# Minibatch loss at step 46700: 2.261782
# Minibatch accuracy: 100.0%
# VALIDATION accuracy: 77.0%
# Minibatch loss at step 46800: 2.510337
# Minibatch accuracy: 80.0%
# VALIDATION accuracy: 76.9%
# Minibatch loss at step 46900: 2.584029
# Minibatch accuracy: 80.0%
# VALIDATION accuracy: 76.9%
# Minibatch loss at step 47000: 2.313704
# Minibatch accuracy: 80.0%
# VALIDATION accuracy: 77.0%
# Minibatch loss at step 47100: 3.018642
# Minibatch accuracy: 60.0%
# VALIDATION accuracy: 77.0%
# Minibatch loss at step 47200: 2.841116
# Minibatch accuracy: 60.0%
# VALIDATION accuracy: 77.0%
# Minibatch loss at step 47300: 2.406742
# Minibatch accuracy: 80.0%
# VALIDATION accuracy: 76.9%
# Minibatch loss at step 47400: 3.384052
# Minibatch accuracy: 20.0%
# VALIDATION accuracy: 76.8%
# Minibatch loss at step 47500: 2.250511
# Minibatch accuracy: 100.0%
# VALIDATION accuracy: 76.8%
# Minibatch loss at step 47600: 2.915256
# Minibatch accuracy: 60.0%
# VALIDATION accuracy: 76.8%
# Minibatch loss at step 47700: 2.546520
# Minibatch accuracy: 80.0%
# VALIDATION accuracy: 76.8%
# Minibatch loss at step 47800: 2.737668
# Minibatch accuracy: 40.0%
# VALIDATION accuracy: 76.8%
# Minibatch loss at step 47900: 2.843220
# Minibatch accuracy: 80.0%
# VALIDATION accuracy: 76.8%
# Minibatch loss at step 48000: 2.158445
# Minibatch accuracy: 100.0%
# VALIDATION accuracy: 76.8%
# Minibatch loss at step 48100: 2.655269
# Minibatch accuracy: 80.0%
# VALIDATION accuracy: 76.8%
# Minibatch loss at step 48200: 2.137738
# Minibatch accuracy: 100.0%
# VALIDATION accuracy: 76.8%
# Minibatch loss at step 48300: 2.631705
# Minibatch accuracy: 60.0%
# VALIDATION accuracy: 76.8%
# Minibatch loss at step 48400: 2.263079
# Minibatch accuracy: 100.0%
# VALIDATION accuracy: 76.8%
# Minibatch loss at step 48500: 2.174671
# Minibatch accuracy: 100.0%
# VALIDATION accuracy: 76.8%
# Minibatch loss at step 48600: 2.357991
# Minibatch accuracy: 80.0%
# VALIDATION accuracy: 76.8%
# Minibatch loss at step 48700: 2.504781
# Minibatch accuracy: 80.0%
# VALIDATION accuracy: 77.0%
# Minibatch loss at step 48800: 2.687983
# Minibatch accuracy: 60.0%
# VALIDATION accuracy: 76.8%
# Minibatch loss at step 48900: 2.488729
# Minibatch accuracy: 80.0%
# VALIDATION accuracy: 76.9%
# Minibatch loss at step 49000: 2.538383
# Minibatch accuracy: 60.0%
# VALIDATION accuracy: 76.9%
# Minibatch loss at step 49100: 2.469174
# Minibatch accuracy: 80.0%
# VALIDATION accuracy: 76.9%
# Minibatch loss at step 49200: 2.122572
# Minibatch accuracy: 100.0%
# VALIDATION accuracy: 77.0%
# Minibatch loss at step 49300: 2.976026
# Minibatch accuracy: 60.0%
# VALIDATION accuracy: 76.9%
# Minibatch loss at step 49400: 2.432383
# Minibatch accuracy: 100.0%
# VALIDATION accuracy: 76.9%
# Minibatch loss at step 49500: 2.765688
# Minibatch accuracy: 60.0%
# VALIDATION accuracy: 76.9%
# Minibatch loss at step 49600: 2.267342
# Minibatch accuracy: 80.0%
# VALIDATION accuracy: 76.8%
# Minibatch loss at step 49700: 2.564139
# Minibatch accuracy: 60.0%
# VALIDATION accuracy: 76.8%
# Minibatch loss at step 49800: 2.868629
# Minibatch accuracy: 60.0%
# VALIDATION accuracy: 76.8%
# Minibatch loss at step 49900: 3.236076
# Minibatch accuracy: 60.0%
# VALIDATION accuracy: 76.8%
# Minibatch loss at step 50000: 2.630949
# Minibatch accuracy: 80.0%
# VALIDATION accuracy: 76.8%
# Minibatch loss at step 50100: 2.933856
# Minibatch accuracy: 80.0%
# VALIDATION accuracy: 76.8%
# Minibatch loss at step 50200: 2.216902
# Minibatch accuracy: 100.0%
# VALIDATION accuracy: 76.8%
# Minibatch loss at step 50300: 2.346488
# Minibatch accuracy: 80.0%
# VALIDATION accuracy: 76.8%
# Minibatch loss at step 50400: 2.624924
# Minibatch accuracy: 60.0%
# VALIDATION accuracy: 76.8%
# Minibatch loss at step 50500: 2.343556
# Minibatch accuracy: 60.0%
# VALIDATION accuracy: 76.8%
# Minibatch loss at step 50600: 2.594613
# Minibatch accuracy: 80.0%
# VALIDATION accuracy: 76.8%
# Minibatch loss at step 50700: 2.345818
# Minibatch accuracy: 100.0%
# VALIDATION accuracy: 76.8%
# Minibatch loss at step 50800: 2.296197
# Minibatch accuracy: 80.0%
# VALIDATION accuracy: 76.9%
# Minibatch loss at step 50900: 2.237144
# Minibatch accuracy: 80.0%
# VALIDATION accuracy: 76.9%
# Minibatch loss at step 51000: 3.370653
# Minibatch accuracy: 40.0%
# VALIDATION accuracy: 76.9%
# Minibatch loss at step 51100: 2.579463
# Minibatch accuracy: 60.0%
# VALIDATION accuracy: 76.9%
# Minibatch loss at step 51200: 2.708878
# Minibatch accuracy: 80.0%
# VALIDATION accuracy: 76.9%
# Minibatch loss at step 51300: 2.438861
# Minibatch accuracy: 80.0%
# VALIDATION accuracy: 76.9%
# Minibatch loss at step 51400: 2.669121
# Minibatch accuracy: 80.0%
# VALIDATION accuracy: 76.9%
# Minibatch loss at step 51500: 2.508054
# Minibatch accuracy: 40.0%
# VALIDATION accuracy: 76.9%
# Minibatch loss at step 51600: 2.399962
# Minibatch accuracy: 100.0%
# VALIDATION accuracy: 76.9%
# Minibatch loss at step 51700: 2.552103
# Minibatch accuracy: 80.0%
# VALIDATION accuracy: 76.9%
# Minibatch loss at step 51800: 2.111323
# Minibatch accuracy: 100.0%
# VALIDATION accuracy: 76.8%
# Minibatch loss at step 51900: 2.710577
# Minibatch accuracy: 60.0%
# VALIDATION accuracy: 76.8%
# Minibatch loss at step 52000: 2.363070
# Minibatch accuracy: 80.0%
# VALIDATION accuracy: 76.8%
# Minibatch loss at step 52100: 2.809581
# Minibatch accuracy: 60.0%
# VALIDATION accuracy: 76.8%
# Minibatch loss at step 52200: 3.010587
# Minibatch accuracy: 20.0%
# VALIDATION accuracy: 76.8%
# Minibatch loss at step 52300: 3.191523
# Minibatch accuracy: 60.0%
# VALIDATION accuracy: 76.8%
# Minibatch loss at step 52400: 2.444382
# Minibatch accuracy: 80.0%
# VALIDATION accuracy: 76.8%
# Minibatch loss at step 52500: 2.242075
# Minibatch accuracy: 100.0%
# VALIDATION accuracy: 76.8%
# Minibatch loss at step 52600: 2.527684
# Minibatch accuracy: 80.0%
# VALIDATION accuracy: 76.8%
# Minibatch loss at step 52700: 2.397963
# Minibatch accuracy: 80.0%
# VALIDATION accuracy: 76.8%
# Minibatch loss at step 52800: 2.779224
# Minibatch accuracy: 40.0%
# VALIDATION accuracy: 76.8%
# Minibatch loss at step 52900: 2.255505
# Minibatch accuracy: 100.0%
# VALIDATION accuracy: 76.8%
# Minibatch loss at step 53000: 2.672394
# Minibatch accuracy: 60.0%
# VALIDATION accuracy: 76.9%
# Minibatch loss at step 53100: 2.019056
# Minibatch accuracy: 100.0%
# VALIDATION accuracy: 76.8%
# Minibatch loss at step 53200: 2.863083
# Minibatch accuracy: 60.0%
# VALIDATION accuracy: 76.9%
# Minibatch loss at step 53300: 2.624870
# Minibatch accuracy: 80.0%
# VALIDATION accuracy: 76.9%
# Minibatch loss at step 53400: 2.756542
# Minibatch accuracy: 60.0%
# VALIDATION accuracy: 76.9%
# Minibatch loss at step 53500: 2.355591
# Minibatch accuracy: 80.0%
# VALIDATION accuracy: 76.9%
# Minibatch loss at step 53600: 2.372468
# Minibatch accuracy: 80.0%
# VALIDATION accuracy: 76.8%
# Minibatch loss at step 53700: 2.545920
# Minibatch accuracy: 80.0%
# VALIDATION accuracy: 76.9%
# Minibatch loss at step 53800: 2.559760
# Minibatch accuracy: 80.0%
# VALIDATION accuracy: 76.8%
# Minibatch loss at step 53900: 2.398614
# Minibatch accuracy: 80.0%
# VALIDATION accuracy: 76.9%
# Minibatch loss at step 54000: 2.613274
# Minibatch accuracy: 60.0%
# VALIDATION accuracy: 76.8%
# Minibatch loss at step 54100: 2.548904
# Minibatch accuracy: 60.0%
# VALIDATION accuracy: 76.8%
# Minibatch loss at step 54200: 2.694721
# Minibatch accuracy: 80.0%
# VALIDATION accuracy: 76.8%
# Minibatch loss at step 54300: 2.437320
# Minibatch accuracy: 60.0%
# VALIDATION accuracy: 76.8%
# Minibatch loss at step 54400: 2.668581
# Minibatch accuracy: 60.0%
# VALIDATION accuracy: 76.8%
# Minibatch loss at step 54500: 2.827647
# Minibatch accuracy: 60.0%
# VALIDATION accuracy: 76.8%
# Minibatch loss at step 54600: 2.173733
# Minibatch accuracy: 100.0%
# VALIDATION accuracy: 76.8%
# Minibatch loss at step 54700: 2.408616
# Minibatch accuracy: 80.0%
# VALIDATION accuracy: 76.8%
# Minibatch loss at step 54800: 2.287241
# Minibatch accuracy: 80.0%
# VALIDATION accuracy: 76.8%
# Minibatch loss at step 54900: 2.565673
# Minibatch accuracy: 60.0%
# VALIDATION accuracy: 76.8%
# Minibatch loss at step 55000: 2.231816
# Minibatch accuracy: 100.0%
# VALIDATION accuracy: 76.8%
# Minibatch loss at step 55100: 2.817542
# Minibatch accuracy: 60.0%
# VALIDATION accuracy: 76.8%
# Minibatch loss at step 55200: 2.379945
# Minibatch accuracy: 80.0%
# VALIDATION accuracy: 76.8%
# Minibatch loss at step 55300: 2.575195
# Minibatch accuracy: 80.0%
# VALIDATION accuracy: 76.9%
# Minibatch loss at step 55400: 2.330385
# Minibatch accuracy: 100.0%
# VALIDATION accuracy: 76.8%
# Minibatch loss at step 55500: 2.222195
# Minibatch accuracy: 100.0%
# VALIDATION accuracy: 76.8%
# Minibatch loss at step 55600: 2.337100
# Minibatch accuracy: 100.0%
# VALIDATION accuracy: 76.8%
# Minibatch loss at step 55700: 2.382793
# Minibatch accuracy: 80.0%
# VALIDATION accuracy: 76.8%
# Minibatch loss at step 55800: 2.367656
# Minibatch accuracy: 100.0%
# VALIDATION accuracy: 76.8%
# Minibatch loss at step 55900: 2.210725
# Minibatch accuracy: 100.0%
# VALIDATION accuracy: 76.8%
# Minibatch loss at step 56000: 2.456940
# Minibatch accuracy: 80.0%
# VALIDATION accuracy: 76.8%
# Minibatch loss at step 56100: 2.885761
# Minibatch accuracy: 60.0%
# VALIDATION accuracy: 76.8%
# Minibatch loss at step 56200: 2.278291
# Minibatch accuracy: 100.0%
# VALIDATION accuracy: 76.8%
# Minibatch loss at step 56300: 2.268894
# Minibatch accuracy: 100.0%
# VALIDATION accuracy: 76.8%
# Minibatch loss at step 56400: 2.404479
# Minibatch accuracy: 80.0%
# VALIDATION accuracy: 76.8%
# Minibatch loss at step 56500: 2.480455
# Minibatch accuracy: 80.0%
# VALIDATION accuracy: 76.8%
# Minibatch loss at step 56600: 3.171719
# Minibatch accuracy: 60.0%
# VALIDATION accuracy: 76.8%
# Minibatch loss at step 56700: 2.456608
# Minibatch accuracy: 80.0%
# VALIDATION accuracy: 76.8%
# Minibatch loss at step 56800: 2.376216
# Minibatch accuracy: 80.0%
# VALIDATION accuracy: 76.8%
# Minibatch loss at step 56900: 2.367966
# Minibatch accuracy: 80.0%
# VALIDATION accuracy: 76.8%
# Minibatch loss at step 57000: 2.406124
# Minibatch accuracy: 80.0%
# VALIDATION accuracy: 76.8%
# Minibatch loss at step 57100: 2.689849
# Minibatch accuracy: 40.0%
# VALIDATION accuracy: 76.8%
# Minibatch loss at step 57200: 2.181875
# Minibatch accuracy: 100.0%
# VALIDATION accuracy: 76.8%
# Minibatch loss at step 57300: 2.247566
# Minibatch accuracy: 100.0%
# VALIDATION accuracy: 76.8%
# Minibatch loss at step 57400: 2.532176
# Minibatch accuracy: 60.0%
# VALIDATION accuracy: 76.8%
# Minibatch loss at step 57500: 2.631746
# Minibatch accuracy: 60.0%
# VALIDATION accuracy: 76.8%
# Minibatch loss at step 57600: 2.431474
# Minibatch accuracy: 80.0%
# VALIDATION accuracy: 76.8%
# Minibatch loss at step 57700: 2.223306
# Minibatch accuracy: 100.0%
# VALIDATION accuracy: 76.8%
# Minibatch loss at step 57800: 2.508999
# Minibatch accuracy: 60.0%
# VALIDATION accuracy: 76.8%
# Minibatch loss at step 57900: 2.618980
# Minibatch accuracy: 80.0%
# VALIDATION accuracy: 76.8%
# Minibatch loss at step 58000: 2.660330
# Minibatch accuracy: 60.0%
# VALIDATION accuracy: 76.8%
# Minibatch loss at step 58100: 4.439616
# Minibatch accuracy: 40.0%
# VALIDATION accuracy: 76.8%
# Minibatch loss at step 58200: 2.201599
# Minibatch accuracy: 100.0%
# VALIDATION accuracy: 76.8%
# Minibatch loss at step 58300: 2.728427
# Minibatch accuracy: 60.0%
# VALIDATION accuracy: 76.8%
# Minibatch loss at step 58400: 2.135161
# Minibatch accuracy: 100.0%
# VALIDATION accuracy: 76.8%
# Minibatch loss at step 58500: 3.579864
# Minibatch accuracy: 20.0%
# VALIDATION accuracy: 76.8%
# Minibatch loss at step 58600: 2.517583
# Minibatch accuracy: 60.0%
# VALIDATION accuracy: 76.8%
# Minibatch loss at step 58700: 3.425936
# Minibatch accuracy: 60.0%
# VALIDATION accuracy: 76.8%
# Minibatch loss at step 58800: 2.241248
# Minibatch accuracy: 100.0%
# VALIDATION accuracy: 76.8%
# Minibatch loss at step 58900: 2.479325
# Minibatch accuracy: 80.0%
# VALIDATION accuracy: 76.8%
# Minibatch loss at step 59000: 2.889481
# Minibatch accuracy: 40.0%
# VALIDATION accuracy: 76.8%
# Minibatch loss at step 59100: 2.252515
# Minibatch accuracy: 100.0%
# VALIDATION accuracy: 76.8%
# Minibatch loss at step 59200: 2.295913
# Minibatch accuracy: 100.0%
# VALIDATION accuracy: 76.8%
# Minibatch loss at step 59300: 2.155980
# Minibatch accuracy: 100.0%
# VALIDATION accuracy: 76.8%
# Minibatch loss at step 59400: 2.570847
# Minibatch accuracy: 80.0%
# VALIDATION accuracy: 76.8%
# Minibatch loss at step 59500: 3.100556
# Minibatch accuracy: 60.0%
# VALIDATION accuracy: 76.8%
# Minibatch loss at step 59600: 2.610893
# Minibatch accuracy: 60.0%
# VALIDATION accuracy: 76.8%
# Minibatch loss at step 59700: 2.055772
# Minibatch accuracy: 100.0%
# VALIDATION accuracy: 76.8%
# Minibatch loss at step 59800: 2.420558
# Minibatch accuracy: 80.0%
# VALIDATION accuracy: 76.8%
# Minibatch loss at step 59900: 2.429444
# Minibatch accuracy: 80.0%
# VALIDATION accuracy: 76.8%
# Minibatch loss at step 60000: 2.419896
# Minibatch accuracy: 80.0%
# VALIDATION accuracy: 76.8%
# Minibatch loss at step 60100: 2.386434
# Minibatch accuracy: 80.0%
# VALIDATION accuracy: 76.8%
# Minibatch loss at step 60200: 2.235363
# Minibatch accuracy: 100.0%
# VALIDATION accuracy: 76.8%
# Minibatch loss at step 60300: 2.165065
# Minibatch accuracy: 100.0%
# VALIDATION accuracy: 76.8%
# Minibatch loss at step 60400: 2.515428
# Minibatch accuracy: 80.0%
# VALIDATION accuracy: 76.8%
# Minibatch loss at step 60500: 2.692023
# Minibatch accuracy: 60.0%
# VALIDATION accuracy: 76.8%
# Minibatch loss at step 60600: 2.693225
# Minibatch accuracy: 60.0%
# VALIDATION accuracy: 76.8%
# Minibatch loss at step 60700: 2.662230
# Minibatch accuracy: 80.0%
# VALIDATION accuracy: 76.8%
# Minibatch loss at step 60800: 2.380998
# Minibatch accuracy: 80.0%
# VALIDATION accuracy: 76.8%
# Minibatch loss at step 60900: 2.232780
# Minibatch accuracy: 100.0%
# VALIDATION accuracy: 76.8%
# Minibatch loss at step 61000: 2.603164
# Minibatch accuracy: 40.0%
# VALIDATION accuracy: 76.8%
# Minibatch loss at step 61100: 2.474592
# Minibatch accuracy: 60.0%
# VALIDATION accuracy: 76.8%
# Minibatch loss at step 61200: 2.453859
# Minibatch accuracy: 80.0%
# VALIDATION accuracy: 76.8%
# Minibatch loss at step 61300: 2.402312
# Minibatch accuracy: 80.0%
# VALIDATION accuracy: 76.8%
# Minibatch loss at step 61400: 2.368763
# Minibatch accuracy: 80.0%
# VALIDATION accuracy: 76.8%
# Minibatch loss at step 61500: 2.249259
# Minibatch accuracy: 80.0%
# VALIDATION accuracy: 76.8%
# Minibatch loss at step 61600: 3.775798
# Minibatch accuracy: 40.0%
# VALIDATION accuracy: 76.8%
# Minibatch loss at step 61700: 2.665622
# Minibatch accuracy: 60.0%
# VALIDATION accuracy: 76.8%
# Minibatch loss at step 61800: 2.397132
# Minibatch accuracy: 100.0%
# VALIDATION accuracy: 76.8%
# Minibatch loss at step 61900: 3.000239
# Minibatch accuracy: 60.0%
# VALIDATION accuracy: 76.8%
# Minibatch loss at step 62000: 2.121500
# Minibatch accuracy: 100.0%
# VALIDATION accuracy: 76.8%
# Minibatch loss at step 62100: 2.306897
# Minibatch accuracy: 80.0%
# VALIDATION accuracy: 76.8%
# Minibatch loss at step 62200: 2.620532
# Minibatch accuracy: 60.0%
# VALIDATION accuracy: 76.8%
# Minibatch loss at step 62300: 2.069153
# Minibatch accuracy: 100.0%
# VALIDATION accuracy: 76.8%
# Minibatch loss at step 62400: 2.253649
# Minibatch accuracy: 100.0%
# VALIDATION accuracy: 76.8%
# Minibatch loss at step 62500: 2.066776
# Minibatch accuracy: 100.0%
# VALIDATION accuracy: 76.8%
# Minibatch loss at step 62600: 3.006554
# Minibatch accuracy: 40.0%
# VALIDATION accuracy: 76.8%
# Minibatch loss at step 62700: 2.229705
# Minibatch accuracy: 100.0%
# VALIDATION accuracy: 76.8%
# Minibatch loss at step 62800: 2.223712
# Minibatch accuracy: 100.0%
# VALIDATION accuracy: 76.8%
# Minibatch loss at step 62900: 2.378608
# Minibatch accuracy: 80.0%
# VALIDATION accuracy: 76.8%
# Minibatch loss at step 63000: 2.150331
# Minibatch accuracy: 100.0%
# VALIDATION accuracy: 76.8%
# Minibatch loss at step 63100: 2.205117
# Minibatch accuracy: 100.0%
# VALIDATION accuracy: 76.8%
# Minibatch loss at step 63200: 2.589431
# Minibatch accuracy: 80.0%
# VALIDATION accuracy: 76.8%
# Minibatch loss at step 63300: 2.551503
# Minibatch accuracy: 80.0%
# VALIDATION accuracy: 76.8%
# Minibatch loss at step 63400: 2.542356
# Minibatch accuracy: 60.0%
# VALIDATION accuracy: 76.8%
# Minibatch loss at step 63500: 2.701472
# Minibatch accuracy: 60.0%
# VALIDATION accuracy: 76.8%
# Minibatch loss at step 63600: 2.711448
# Minibatch accuracy: 60.0%
# VALIDATION accuracy: 76.8%
# Minibatch loss at step 63700: 2.520994
# Minibatch accuracy: 100.0%
# VALIDATION accuracy: 76.8%
# Minibatch loss at step 63800: 3.054761
# Minibatch accuracy: 40.0%
# VALIDATION accuracy: 76.8%
# Minibatch loss at step 63900: 2.207029
# Minibatch accuracy: 100.0%
# VALIDATION accuracy: 76.8%
# Minibatch loss at step 64000: 2.355666
# Minibatch accuracy: 80.0%
# VALIDATION accuracy: 76.8%
# Minibatch loss at step 64100: 2.978679
# Minibatch accuracy: 60.0%
# VALIDATION accuracy: 76.8%
# Minibatch loss at step 64200: 2.527499
# Minibatch accuracy: 60.0%
# VALIDATION accuracy: 76.8%
# Minibatch loss at step 64300: 2.682733
# Minibatch accuracy: 60.0%
# VALIDATION accuracy: 76.8%
# Minibatch loss at step 64400: 2.823843
# Minibatch accuracy: 60.0%
# VALIDATION accuracy: 76.8%
# Minibatch loss at step 64500: 2.257307
# Minibatch accuracy: 100.0%
# VALIDATION accuracy: 76.8%
# Minibatch loss at step 64600: 2.204942
# Minibatch accuracy: 100.0%
# VALIDATION accuracy: 76.8%
# Minibatch loss at step 64700: 3.659902
# Minibatch accuracy: 60.0%
# VALIDATION accuracy: 76.8%
# Minibatch loss at step 64800: 2.868874
# Minibatch accuracy: 60.0%
# VALIDATION accuracy: 76.8%
# Minibatch loss at step 64900: 2.321103
# Minibatch accuracy: 80.0%
# VALIDATION accuracy: 76.8%
# Minibatch loss at step 65000: 3.053159
# Minibatch accuracy: 40.0%
# VALIDATION accuracy: 76.8%
# Minibatch loss at step 65100: 2.234704
# Minibatch accuracy: 100.0%
# VALIDATION accuracy: 76.8%
# Minibatch loss at step 65200: 2.709530
# Minibatch accuracy: 40.0%
# VALIDATION accuracy: 76.8%
# Minibatch loss at step 65300: 2.339843
# Minibatch accuracy: 80.0%
# VALIDATION accuracy: 76.8%
# Minibatch loss at step 65400: 3.007868
# Minibatch accuracy: 40.0%
# VALIDATION accuracy: 76.8%
# Minibatch loss at step 65500: 2.519611
# Minibatch accuracy: 80.0%
# VALIDATION accuracy: 76.8%
# Minibatch loss at step 65600: 2.310793
# Minibatch accuracy: 100.0%
# VALIDATION accuracy: 76.8%
# Minibatch loss at step 65700: 2.189282
# Minibatch accuracy: 100.0%
# VALIDATION accuracy: 76.8%
# Minibatch loss at step 65800: 3.274425
# Minibatch accuracy: 80.0%
# VALIDATION accuracy: 76.8%
# Minibatch loss at step 65900: 2.964160
# Minibatch accuracy: 40.0%
# VALIDATION accuracy: 76.8%
# Minibatch loss at step 66000: 2.810260
# Minibatch accuracy: 60.0%
# VALIDATION accuracy: 76.8%
# Minibatch loss at step 66100: 2.303697
# Minibatch accuracy: 80.0%
# VALIDATION accuracy: 76.8%
# Minibatch loss at step 66200: 2.963158
# Minibatch accuracy: 80.0%
# VALIDATION accuracy: 76.8%
# Minibatch loss at step 66300: 2.221118
# Minibatch accuracy: 100.0%
# VALIDATION accuracy: 76.8%
# Minibatch loss at step 66400: 2.671337
# Minibatch accuracy: 80.0%
# VALIDATION accuracy: 76.8%
# Minibatch loss at step 66500: 2.781664
# Minibatch accuracy: 80.0%
# VALIDATION accuracy: 76.8%
# Minibatch loss at step 66600: 2.137971
# Minibatch accuracy: 100.0%
# VALIDATION accuracy: 76.8%
# Minibatch loss at step 66700: 2.313404
# Minibatch accuracy: 80.0%
# VALIDATION accuracy: 76.8%
# Minibatch loss at step 66800: 2.812257
# Minibatch accuracy: 60.0%
# VALIDATION accuracy: 76.8%
# Minibatch loss at step 66900: 2.427417
# Minibatch accuracy: 80.0%
# VALIDATION accuracy: 76.8%
# Minibatch loss at step 67000: 2.793052
# Minibatch accuracy: 60.0%
# VALIDATION accuracy: 76.8%
# Minibatch loss at step 67100: 2.314261
# Minibatch accuracy: 80.0%
# VALIDATION accuracy: 76.8%
# Minibatch loss at step 67200: 2.934966
# Minibatch accuracy: 80.0%
# VALIDATION accuracy: 76.8%
# Minibatch loss at step 67300: 3.454651
# Minibatch accuracy: 60.0%
# VALIDATION accuracy: 76.8%
# FINAL TEST accuracy: 76.9%
